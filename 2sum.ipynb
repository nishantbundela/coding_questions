# %% [markdown]
# <a href="https://colab.research.google.com/github/nishantbundela/coding_questions/blob/iteration_1/2sum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.

# %%
def twosum(nums, target):
  hashmap = {}
  for i in range(len(nums)):
    complement = target - nums[i]
    if complement in hashmap:
        print(i, hashmap[complement])
    hashmap[nums[i]] = i

# %%
nums = [2,7,11,15]
target = 9
twosum(nums, target)
# Out:
# 1 0
